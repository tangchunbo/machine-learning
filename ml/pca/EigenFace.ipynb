# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import fetch_lfw_people

# %%
faces = fetch_lfw_people(data_home='../data/mldata/')

# %%
faces.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'target_names', 'DESCR'])

# %%
faces.data.shape
# Out:
# (13233, 2914)

# %%
faces.images.shape
# Out:
# (13233, 62, 47)

# %%
random_indexes = np.random.permutation(len(faces.data))
X = faces.data[random_indexes]

# %%
example_faces = X[:36, :]
example_faces.shape
# Out:
# (36, 2914)

# %%
def plot_digits(data):
    fig, axes = plt.subplots(6, 6, figsize=(10, 10),
                           subplot_kw={'xticks':[], 'yticks':[]},
                           gridspec_kw=dict(hspace=0.1,wspace=0.1))
    for i, ax in enumerate(axes.flat):
        ax.imshow(data[i].reshape(62, 47), cmap='bone')
    plt.show()

# %%
plot_digits(example_faces)

# %%
faces.target_names
# Out:
# array(['AJ Cook', 'AJ Lamas', 'Aaron Eckhart', ..., 'Zumrati Juma',
#        'Zurab Tsereteli', 'Zydrunas Ilgauskas'], dtype='<U35')

# %% [markdown]
# ### 特征脸

# %%
from sklearn.decomposition import PCA
# svd_solver : string {‘auto’, ‘full’, ‘arpack’, ‘randomized’}
pca = PCA(svd_solver='randomized')
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='randomized', tol=0.0, whiten=False)

# %%
pca.components_.shape
# Out:
# (2914, 2914)

# %%
plot_digits(pca.components_[:36, :])

# %%
# 每个人至少60张
faces2 = fetch_lfw_people(min_faces_per_person=60, data_home='../data/mldata/')

# %%
faces2.data.shape
# Out:
# (1348, 2914)

# %%
len(faces2.target_names)
# Out:
# 8
