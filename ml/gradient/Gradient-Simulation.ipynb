# %% [markdown]
# ### 模拟梯度下降

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-1, 6, 150)
y = (x - 2.5) ** 2 - 1

# %%
plt.plot(x, y)
plt.show()

# %%
### 求导
def dJ(theta):
    return 2 * (theta - 2.5)

# %%
def J(theta):
    return (theta - 2.5) ** 2 - 1

# %%
theta = 0.0
eta = 0.1
epsilon = 1e-8
while True:
    gradient = dJ(theta)
    last_theta = theta
    theta = theta - eta * gradient
    
    if(abs(J(theta) - J(last_theta)) < epsilon):
        break

print(theta)
print(J(theta))
# Out:
# 2.499891109642585
# -0.99999998814289

# %%
theta = 0.0
eta = 0.1
epsilon = 1e-8
theta_history = [theta]
while True:
    gradient = dJ(theta)
    last_theta = theta
    theta = theta - eta * gradient
    theta_history.append(theta)
    if(abs(J(theta) - J(last_theta)) < epsilon):
        break

plt.plot(x, y)
plt.plot(np.array(theta_history), J(np.array(theta_history)), color ='r', marker = '+')
plt.show()

# %%
def gradient_descent(init_theta, eta, epslion=1e-8, n_iter=1e4):
    theta = init_theta
    theta_history.append(theta)
    i_iter = 0
    while i_iter < n_iter:
        gradient = dJ(theta)
        last_theta = theta
        theta = theta - eta * gradient
        theta_history.append(theta)
        i_iter += 1
        if(abs(J(theta) - J(last_theta)) < epsilon):
            break
            
def plot_theta_history():
    plt.plot(x, y)
    plt.plot(np.array(theta_history), J(np.array(theta_history)), color ='r', marker = '+')
    plt.show()

# %%
theta_history = []
eta = 0.01
gradient_descent(0., eta)
plot_theta_history()

# %%
theta_history = []
eta = 0.8
gradient_descent(0., eta)
plot_theta_history()

# %%
theta_history = []
eta = 1.1
gradient_descent(0., eta, n_iter=10)
plot_theta_history()
